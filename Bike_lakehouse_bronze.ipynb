# %% [markdown]
# **bronze**

# %%
df=spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/bronze/source_system/cust_info.csv")
df.display()

# %% [markdown]
# **Write to bronze layer**

# %%
spark.sql("DROP TABLE IF EXISTS bronze.crm_cust_info")
df.write.mode("overwrite").saveAsTable("bronze.crm_cust_info")

# %%
# %sql
select * from workspace.bronze.crm_cust_info

# %%
df_prd=spark.read.option("header","true").option("inferSchema","true").csv("/Volumes/workspace/bronze/source_system/prd_info.csv")
df_prd.display()

# %%
# %sql
drop table if exists workspace.bronze.crmprd_info;

# %%
df_prd.write.mode("overwrite").saveAsTable("bronze.crm_prd_info")
